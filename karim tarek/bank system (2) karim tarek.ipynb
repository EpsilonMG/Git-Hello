# %%
class User:
    
    def __init__(self, name, age, gender,Id,password):
        self.name = name
        self.age = age
        self.gender = gender
        self.Id = Id
        self.password = password
        print("account created successfuly!")
        #bank().enterv()
    def set_name(self, new_name):
            self.name = new_name
        
    def set_name(self, new_age):
            self.name = new_age
        
    def set_name(self, new_gender):
            self.name = new_gender
        
    def getName(self):
        return self.name
    def getage(self):
        return self.age
    def getgender(self):
        return self.gender
    def getInfo(self):
        print (" Name : ",self.name,"\n Age : ",self.age,"\n Gender : ",self.gender)
        
class bank(User):
    
    def __init__(self, accountbalance=100, amount=0):
        self.accountbalance = accountbalance
        self.amount = amount    
    def set_balance(self, new_balance):
            self.accountbalance = new_balance
        
    def set_amount(self, new_age):
            self.amount = new_age 
    def getbalance(self):
            print("account balance is equal:",self.accountbalance)
    def getamount(self):
            return self.amount
    def deposit(self):
            self.accountbalance=self.accountbalance+self.amount
            print ("balance became:",self.accountbalance)
        
    def withdraw(self):
        self.accountbalance=self.accountbalance-self.amount
        print ("balnce withdrawed to be:",self.accountbalance)
        
    #def getbalance(self):
     #   print ("account balance is :",self.accountbalance)
      #  bank().enterv()
    
def main():
    
    c1=bank()
    name=input("enter your name : ")
    age=input("enter your age : ")
    gender=input("enter your gender : ")
    Id=input("enter your id number : ")
    password=input("enter your password : ")
    d1=User(name,age,gender,Id,password)
    while True:
        v=int(input("1 to show all details account\n2 to show account balance\n3 to withdraw\n4 to deposit\n5 to sign out\n0 to exit\n"))
        pos=input("enter your password : ")
        try:
            if pos == password:
                    if v == 1:
                        d1.getInfo()
                    elif v == 2:
                        c1.getbalance()
                    elif v == 3:
                        n=int(input("enter amount to draw "))
                        c1.set_amount(n)
                        c1.withdraw()
                    elif v == 4:
                        n=int(input("enter amount to deposit "))
                        c1.set_amount(n)
                        c1.deposit()
                    elif v == 5:
                        name=input("enter your name : ")
                        age=input("enter your age : ")
                        gender=input("enter your gender : ")
                        Id=input("enter your id number : ")
                        password=input("enter your password : ")
                        d1=User(name,age,gender,Id,password)
                    elif v == 0:
                        print("thanks for using our system ;)")
                        break
            else:
                print("this is a wrong password: ")
        except ValueError:
            print("Value Error")
    
if __name__ == "__main__":
    main()
# Out:
# enter your name : 213
# enter your age : 12
# enter your gender : male
# enter your id number : 123
# enter your password : 111
# account created successfuly!
# 1 to show all details account
# 2 to show account balance
# 3 to withdraw
# 4 to deposit
# 5 to sign out
# 0 to exit
# 1
# enter your password : 111
#  Name :  213
#  Age :  12
#  Gender :  male
# 1 to show all details account
# 2 to show account balance
# 3 to withdraw
# 4 to deposit
# 5 to sign out
# 0 to exit
# 2
# enter your password : 111
# account balance is equal: 100
# 1 to show all details account
# 2 to show account balance
# 3 to withdraw
# 4 to deposit
# 5 to sign out
# 0 to exit
# 3
# enter your password : 200
# this is a wrong password:
# 1 to show all details account
# 2 to show account balance
# 3 to withdraw
# 4 to deposit
# 5 to sign out
# 0 to exit
# 3
# enter your password : 111
# enter amount to draw 200
# balnce withdrawed to be: -100
# 1 to show all details account
# 2 to show account balance
# ...
