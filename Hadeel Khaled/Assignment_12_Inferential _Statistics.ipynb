# %% [markdown]
# <h1><center><font color='midnightblue'> Assignment Of Inferential Statistics:</font></center></h1>

# %%
import pandas as pd

# %% [markdown]
# <h1><center><font color='crimson'> Steps to clean the data:</font></center></h1>

# %% [markdown]
# <h2><center><font color='blue'> 1) Reading the whole file:</font></center></h2>

# %%
ab_data = pd.read_csv('ab_data.csv')
ab_data
# Out:
#         user_id                   timestamp      group landing_page  converted
# 0        851104  2017-01-21 22:11:48.556739    control     old_page          0
# 1        804228  2017-01-12 08:01:45.159739    control     old_page          0
# 2        661590  2017-01-11 16:55:06.154213  treatment     new_page          0
# 3        853541  2017-01-08 18:28:03.143765  treatment     new_page          0
# 4        864975  2017-01-21 01:52:26.210827    control     old_page          1
# ...         ...                         ...        ...          ...        ...
# 294473   751197  2017-01-03 22:28:38.630509    control     old_page          0
# 294474   945152  2017-01-12 00:51:57.078372    control     old_page          0
# 294475   734608  2017-01-22 11:45:03.439544    control     old_page          0
# 294476   697314  2017-01-15 01:20:28.957438    control     old_page          0
# 294477   715931  2017-01-16 12:40:24.467417  treatment     new_page          0
#
# ...

# %% [markdown]
# <h2><center><font color='blue'> 2) Printing the first five rows of the file:</font></center></h2>

# %%
ab_data.head()
# Out:
#    user_id                   timestamp      group landing_page  converted
# 0   851104  2017-01-21 22:11:48.556739    control     old_page          0
# 1   804228  2017-01-12 08:01:45.159739    control     old_page          0
# 2   661590  2017-01-11 16:55:06.154213  treatment     new_page          0
# 3   853541  2017-01-08 18:28:03.143765  treatment     new_page          0
# 4   864975  2017-01-21 01:52:26.210827    control     old_page          1

# %% [markdown]
# <h2><center><font color='blue'> 3) Printing the information of the file:</font></center></h2>

# %%
ab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294478 entries, 0 to 294477
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       294478 non-null  int64
#  1   timestamp     294478 non-null  object
#  2   group         294478 non-null  object
#  3   landing_page  294478 non-null  object
#  4   converted     294478 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 7.9+ MB

# %% [markdown]
# <h2><center><font color='blue'> 4) Printing the describtion of the file:</font></center></h2>

# %%
ab_data.describe()
# Out:
#              user_id      converted
# count  294478.000000  294478.000000
# mean   787974.124733       0.119659
# std     91210.823776       0.324563
# min    630000.000000       0.000000
# 25%    709032.250000       0.000000
# 50%    787933.500000       0.000000
# 75%    866911.750000       0.000000
# max    945999.000000       1.000000

# %% [markdown]
# <h2><center><font color='blue'> 5) Printing the number of rows and coloumns of the file:</font></center></h2>

# %%
ab_data.shape
# Out:
# (294478, 5)

# %% [markdown]
# <h2><center><font color='blue'> 6) Checking if there is any null values:</font></center></h2>

# %%
ab_data.isnull().any()
# Out:
# user_id         False
# timestamp       False
# group           False
# landing_page    False
# converted       False
# dtype: bool

# %% [markdown]
# <h3><font color='limegreen'> There is no any null values.</font></h3>

# %% [markdown]
# <h2><center><font color='blue'> 7) Checking if there is any duplicated values:</font></center></h2>

# %%
ab_data['user_id'].nunique()
# Out:
# 290584

# %% [markdown]
# <h3><font color='limegreen'> Here it shows that there is many duplicated values:<br>There is 3,894 duplicated values.</font></h3>

# %%
print("The length of data before removing any duplicated values: " , len(ab_data))
print("The length of data with only the unique values: " , ab_data['user_id'].nunique())
# Out:
# The length of data before removing any duplicated values:  294478
# The length of data with only the unique values:  290584

# %%
ab_data['user_id'].value_counts().nunique()
# Out:
# 2

# %%
repeated = ab_data['user_id'].value_counts()

# %%
duplicated1 = repeated[repeated > 1]
duplicated1
# Out:
# 637561    2
# 821876    2
# 643869    2
# 938802    2
# 916765    2
#          ..
# 764658    2
# 692496    2
# 711355    2
# 813603    2
# 701024    2
# Name: user_id, Length: 3894, dtype: int64

# %%
duplicated2 = repeated[repeated > 1].index
duplicated2
# Out:
# Int64Index([637561, 821876, 643869, 938802, 916765, 690255, 737500, 680018,
#             853835, 736746,
#             ...
#             774079, 859519, 670799, 766516, 694299, 764658, 692496, 711355,
#             813603, 701024],
#            dtype='int64', length=3894)

# %%
user_id = duplicated2.tolist()
user_id
# Out:
# [637561,
#  821876,
#  643869,
#  938802,
#  916765,
#  690255,
#  737500,
#  680018,
#  853835,
#  736746,
#  722827,
#  904340,
#  757485,
#  863300,
#  905507,
#  902109,
#  782432,
#  644294,
#  899374,
#  881704,
#  656951,
#  869729,
#  720460,
#  889529,
#  812376,
#  846972,
#  776770,
#  859842,
#  844475,
#  848746,
#  878310,
#  663125,
#  833499,
#  860245,
#  894671,
#  877223,
#  751643,
#  922905,
#  647115,
#  859416,
#  845661,
#  931254,
#  822919,
#  787637,
#  798046,
#  823120,
#  750316,
#  664419,
#  871800,
#  707283,
#  644426,
#  939267,
#  757033,
#  899828,
#  773339,
#  726921,
#  882002,
#  727648,
#  819986,
#  851806,
#  794347,
#  787083,
#  712312,
#  817933,
#  822436,
#  680574,
#  749179,
#  748263,
#  912705,
#  945227,
#  849419,
#  860573,
#  728596,
#  839180,
#  853857,
#  749217,
#  716366,
#  828083,
#  646077,
#  700036,
#  661926,
#  850866,
#  898232,
#  914055,
#  716469,
#  756804,
#  842816,
#  818060,
#  791192,
#  822877,
# ...

# %%
user_id_2 = pd.DataFrame(user_id)
user_id_2
# Out:
#            0
# 0     637561
# 1     821876
# 2     643869
# 3     938802
# 4     916765
# ...      ...
# 3889  764658
# 3890  692496
# 3891  711355
# 3892  813603
# 3893  701024
#
# [3894 rows x 1 columns]

# %%
duplicated_data = ab_data[ab_data.user_id.isin(user_id)]
duplicated_data
# Out:
#         user_id                   timestamp      group landing_page  converted
# 22       767017  2017-01-12 22:58:14.991443    control     new_page          0
# 192      656468  2017-01-18 07:13:29.805052  treatment     new_page          1
# 226      773693  2017-01-23 18:05:45.167335    control     old_page          1
# 240      733976  2017-01-11 15:11:16.407599    control     new_page          0
# 246      704650  2017-01-04 19:10:52.655062  treatment     new_page          0
# ...         ...                         ...        ...          ...        ...
# 294308   905197  2017-01-03 06:56:47.488231  treatment     new_page          0
# 294309   787083  2017-01-17 00:15:20.950723    control     old_page          0
# 294328   641570  2017-01-09 21:59:27.695711    control     old_page          0
# 294331   689637  2017-01-13 11:34:28.339532    control     new_page          0
# 294355   744456  2017-01-13 09:32:07.106794  treatment     new_page          0
#
# [7788 rows x 5 columns]

# %%
new_ab_data = ab_data.drop(duplicated_data.index)

# %% [markdown]
# <h3><font color='limegreen'> Here it shows that there is no more duplicated values.</font></h3>

# %%
new_ab_data['user_id'].nunique()
# Out:
# 286690

# %%
print("The length of data before removing any duplicated values: " , len(ab_data))
print("The length of data after removing all duplicated values: " , len(new_ab_data))
# Out:
# The length of data before removing any duplicated values:  294478
# The length of data after removing all duplicated values:  286690

# %%
if new_ab_data['user_id'].nunique() == len(new_ab_data) :
    print("There is no duplicated values.")
# Out:
# There is no duplicated values.

# %% [markdown]
# <h2><center><font color='blue'> 8) The Data Shouldn’t include users their Groups is
# ‘treatment’ and the landing page is ‘old_page ‘:</font></center></h2>

# %%
treatment = new_ab_data[new_ab_data['group'] == 'treatment']
treatment
# Out:
#         user_id                   timestamp      group landing_page  converted
# 2        661590  2017-01-11 16:55:06.154213  treatment     new_page          0
# 3        853541  2017-01-08 18:28:03.143765  treatment     new_page          0
# 6        679687  2017-01-19 03:26:46.940749  treatment     new_page          1
# 8        817355  2017-01-04 17:58:08.979471  treatment     new_page          1
# 9        839785  2017-01-15 18:11:06.610965  treatment     new_page          1
# ...         ...                         ...        ...          ...        ...
# 294462   677163  2017-01-03 19:41:51.902148  treatment     new_page          0
# 294465   925675  2017-01-07 20:38:26.346410  treatment     new_page          0
# 294468   643562  2017-01-02 19:20:05.460595  treatment     new_page          0
# 294472   822004  2017-01-04 03:36:46.071379  treatment     new_page          0
# 294477   715931  2017-01-16 12:40:24.467417  treatment     new_page          0
#
# ...

# %%
old = treatment['landing_page'] == 'old_page'
old
# Out:
# 2         False
# 3         False
# 6         False
# 8         False
# 9         False
#           ...
# 294462    False
# 294465    False
# 294468    False
# 294472    False
# 294477    False
# Name: landing_page, Length: 143397, dtype: bool

# %% [markdown]
# <h3><font color='limegreen'> Here it shows that there is no users having their group is treatment and their landing_page is old_page.</font></h3>

# %%
print("The users whose group is TREATMENT: " , len(treatment))
print("The users whose group is TREATMENT and landing_page is NEW_PAGE: " , len(old))
# Out:
# The users whose group is TREATMENT:  143397
# The users whose group is TREATMENT and landing_page is NEW_PAGE:  143397

# %% [markdown]
# <h2><center><font color='blue'> 9) The Data Shouldn’t include users their Groups is ‘control’ and the landing page is ‘new_page’ :</font></center></h2>

# %%
control = new_ab_data[new_ab_data['group'] == 'control']
control
# Out:
#         user_id                   timestamp    group landing_page  converted
# 0        851104  2017-01-21 22:11:48.556739  control     old_page          0
# 1        804228  2017-01-12 08:01:45.159739  control     old_page          0
# 4        864975  2017-01-21 01:52:26.210827  control     old_page          1
# 5        936923  2017-01-10 15:20:49.083499  control     old_page          0
# 7        719014  2017-01-17 01:48:29.539573  control     old_page          0
# ...         ...                         ...      ...          ...        ...
# 294471   718310  2017-01-21 22:44:20.378320  control     old_page          0
# 294473   751197  2017-01-03 22:28:38.630509  control     old_page          0
# 294474   945152  2017-01-12 00:51:57.078372  control     old_page          0
# 294475   734608  2017-01-22 11:45:03.439544  control     old_page          0
# 294476   697314  2017-01-15 01:20:28.957438  control     old_page          0
#
# [143293 rows x 5 columns]

# %%
new = control['landing_page'] == 'new_page'
new
# Out:
# 0         False
# 1         False
# 4         False
# 5         False
# 7         False
#           ...
# 294471    False
# 294473    False
# 294474    False
# 294475    False
# 294476    False
# Name: landing_page, Length: 143293, dtype: bool

# %% [markdown]
# <h3><font color='limegreen'> Here it shows that there is no users having their group is control and their landing_page is new_page.</font></h3>

# %%
print("The users whose group is CONTROL: " , len(control))
print("The users whose group is CONTROL and landing_page is OLD_PAGE: " , len(new))
# Out:
# The users whose group is CONTROL:  143293
# The users whose group is CONTROL and landing_page is OLD_PAGE:  143293

# %% [markdown]
# <h2><center><font color='crimson'> Now the file is clean of any errors:</font></center></h2>

# %%
new_ab_data
# Out:
#         user_id                   timestamp      group landing_page  converted
# 0        851104  2017-01-21 22:11:48.556739    control     old_page          0
# 1        804228  2017-01-12 08:01:45.159739    control     old_page          0
# 2        661590  2017-01-11 16:55:06.154213  treatment     new_page          0
# 3        853541  2017-01-08 18:28:03.143765  treatment     new_page          0
# 4        864975  2017-01-21 01:52:26.210827    control     old_page          1
# ...         ...                         ...        ...          ...        ...
# 294473   751197  2017-01-03 22:28:38.630509    control     old_page          0
# 294474   945152  2017-01-12 00:51:57.078372    control     old_page          0
# 294475   734608  2017-01-22 11:45:03.439544    control     old_page          0
# 294476   697314  2017-01-15 01:20:28.957438    control     old_page          0
# 294477   715931  2017-01-16 12:40:24.467417  treatment     new_page          0
#
# ...
